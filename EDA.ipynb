# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from pylab import rcParams
import datetime as dt
from FinanceDataReader import DataReader, StockListing

# %%
file_path = './Model/005930_final_data/from_2017-07-30.csv'
df=pd.read_csv(file_path,index_col=0)
df.head(1)
# Out:
#             Open_x  High_x  Low_x  Close_x  Volume_x  Change_x  Close_y  \
# Date
# 2017-07-31   47420   48240  46920    48200    254028  0.009213    314.6
#
#             Open_y  High_y  Low_y    Volume_y  Change_y   LG전자  대동전자  대유플러스  \
# Date
# 2017-07-31  312.73  314.81  312.2  82980000.0    0.0015  67100  4570    987
#
#               휴니드  vol_change_x  vol_change_y  Moving_av
# Date
# 2017-07-31  10300           0.0           0.0    48200.0

# %%
df.tail(1)
# Out:
#             Open_x  High_x  Low_x  Close_x  Volume_x  Change_x  Close_y  \
# Date
# 2020-07-30   59700   60100  59000    59100  18230384  0.001695   302.15
#
#             Open_y  High_y  Low_y  Volume_y  Change_y   LG전자  대동전자  대유플러스  \
# Date
# 2020-07-30  302.69  303.44  301.5  183630.0     0.003  72100  4190    640
#
#              휴니드  vol_change_x  vol_change_y  Moving_av
# Date
# 2020-07-30  6990     -1.000869     -0.413004    54770.0

# %% [markdown]
# ### 2018-04-30 부터 2018-05-03동안 액면분할

# %%
df[df['High_x']==0]
# Out:
#             Open_x  High_x  Low_x  Close_x  Volume_x  Change_x  Close_y  \
# Date
# 2018-04-30       0       0      0    53000         0       0.0   323.56
# 2018-05-02       0       0      0    53000         0       0.0   322.53
# 2018-05-03       0       0      0    53000         0       0.0   320.55
#
#             Open_y  High_y   Low_y     Volume_y  Change_y    LG전자  대동전자  \
# Date
# 2018-04-30  321.93  323.58  321.66  139570000.0    0.0086  102000  4095
# 2018-05-02  323.56  323.97  321.99  158300000.0   -0.0032  101500  4095
# 2018-05-03  322.83  322.95  320.55  117280000.0   -0.0061  103000  4110
#
#             대유플러스    휴니드  vol_change_x  vol_change_y  Moving_av
# Date
# 2018-04-30   1040  11100          -inf      0.339471    50245.0
# 2018-05-02   1040  11150           NaN      0.118320    50489.0
# 2018-05-03   1060  11500           NaN     -0.349761    50793.0

# %%
df[df['Low_x']==0]
# Out:
#             Open_x  High_x  Low_x  Close_x  Volume_x  Change_x  Close_y  \
# Date
# 2018-04-30       0       0      0    53000         0       0.0   323.56
# 2018-05-02       0       0      0    53000         0       0.0   322.53
# 2018-05-03       0       0      0    53000         0       0.0   320.55
#
#             Open_y  High_y   Low_y     Volume_y  Change_y    LG전자  대동전자  \
# Date
# 2018-04-30  321.93  323.58  321.66  139570000.0    0.0086  102000  4095
# 2018-05-02  323.56  323.97  321.99  158300000.0   -0.0032  101500  4095
# 2018-05-03  322.83  322.95  320.55  117280000.0   -0.0061  103000  4110
#
#             대유플러스    휴니드  vol_change_x  vol_change_y  Moving_av
# Date
# 2018-04-30   1040  11100          -inf      0.339471    50245.0
# 2018-05-02   1040  11150           NaN      0.118320    50489.0
# 2018-05-03   1060  11500           NaN     -0.349761    50793.0

# %%
def plot_price(colname, style='b-'):
    rcParams['figure.figsize'] = 12, 4
    ax = df[colname].plot(grid=True, style=style)
    ax.set_xlabel('date')
    ax.set_ylabel('price')

# %%
plot_price('High_x')

# %%
plot_price('High_y', style='r-')

# %%
plot_price('Low_x')

# %%
plot_price('Low_y', style='r-')

# %%
plot_price('Volume_x')

# %%
plot_price('Volume_y', style='r-')

# %%
plot_price('Change_x')

# %%
plot_price('Change_y', style='r-')

# %% [markdown]
# ### Close price of Samsung and KOSPI index

# %%
plot_price('Close_x')

# %%
plot_price('Close_y', style='r-')

# %%
plt.plot(df['Close_x'])
plt.plot(df['LG전자'])
plt.plot(df['대동전자'])
plt.plot(df['대유플러스'])
plt.plot(df['휴니드'])

# %% [markdown]
# ### Moving Average

# %%
df.columns
# Out:
# Index(['Open_x', 'High_x', 'Low_x', 'Close_x', 'Volume_x', 'Change_x',
#        'Close_y', 'Open_y', 'High_y', 'Low_y', 'Volume_y', 'Change_y', 'LG전자',
#        '대동전자', '대유플러스', '휴니드', 'vol_change_x', 'vol_change_y', 'Moving_av'],
#       dtype='object')

# %%
def moving_average(df, compare='Close_x', window=10, min_periods=0):
    # plot
    rcParams['figure.figsize'] = 12, 4  # width 12, height 4
    ax = df['Moving_av'].plot(style='b-', grid=True)
    ax = df[compare].plot(style='r-', grid=True)

# %%
moving_average(df, window=5, min_periods=0)

# %%
moving_average(df, window=10, min_periods=0)

# %%
moving_average(df, window=20, min_periods=0)

# %%
moving_average(df, window=30, min_periods=0)

# %%
moving_average(df, window=40, min_periods=0)
